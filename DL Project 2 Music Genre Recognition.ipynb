# %%
# %matplotlib inline

import os
import shutil
import random

from glob import glob
import numpy as np

from tensorflow.keras import layers,regularizers, optimizers
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LeakyReLU,Dense, Activation, Flatten, Dropout, BatchNormalization,Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import librosa
import librosa.display
import matplotlib.pyplot as plt
from matplotlib import figure

# %%
def create_spectrogram(filename,name,store_path):
    plt.interactive(False)
    clip, sample_rate = librosa.load(filename, sr=None)
    fig = plt.figure(figsize=[0.72,0.72])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y=clip, sr=sample_rate)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    filename  = store_path + name + '.jpg'
    plt.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)
    plt.close()    
    fig.clf()
    plt.close(fig)
    plt.close('all')
    del filename,name,clip,sample_rate,fig,ax,S

# %%
def convert_Audio_File_to_jpg_file(filename):
    # make dic for given class and their filepath name
    file_list=list(glob(filename + "\\*"))
    file_dic = {}
    for i,file in enumerate(file_list):
        all_files = []
        for root, dirs, files in os.walk(file):
            for file_ in files:
                # Join the root directory with the file name to get the full path
                all_files.append(os.path.join(root, file_))
        file_dic[file] = all_files
        
    # create file directory to store the converted audio file in to jpg
    file_path = []
    for file in file_dic.keys():
        file_rot = r'Convert_Music_Genre_File_to_jpg_file' + '\\' + file + '\\'
        file_path.append(file_rot)
        os.makedirs(file_rot, exist_ok=True)

    # Here each file is converted into jpg file using spectrogram and stored in above created directory.
    for i,folder in enumerate(file_dic.keys()):
        music_files = file_dic[folder]
        for file in music_files:
          create_spectrogram(file,file.split('\\')[-1],file_path[i])

# %%
convert_Audio_File_to_jpg_file('genres')

# %%
source_dir = r"C:\Users\WIN10\Desktop\IIT Kanpur ML AI Course\Deep Learning\Music Genre Recognition\Convert_Music_Genre_File_to_jpg_file\genres"
target_dir = r'C:\Users\WIN10\Desktop\IIT Kanpur ML AI Course\Deep Learning\Music Genre Recognition\genres_train_val_split_data\genres'
split_ratio = 0.8

def Train_Test_Split(source_dir,target_dir,split_ratio):
    # Define source and target directories
    train_dir = os.path.join(target_dir, 'train')
    val_dir = os.path.join(target_dir, 'val')
    
    # Create target directories if they don't exist
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    
    # Get the list of class directories
    classes = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
        
    for class_name in classes:
        # Create class directories in train and val folders
        os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
        os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)
        
        # Get list of images in the class directory
        class_dir = os.path.join(source_dir, class_name)
        images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
        
        # Shuffle the images
        random.shuffle(images)
        
        # Compute the split point
        split_point = int(len(images) * split_ratio)
        
        # Split the images into training and validation sets
        train_images = images[:split_point]
        val_images = images[split_point:]
        
        # Move the images to the respective directories
        for img in train_images:
            shutil.copy(os.path.join(class_dir, img), os.path.join(train_dir, class_name, img))
        
        for img in val_images:
            shutil.copy(os.path.join(class_dir, img), os.path.join(val_dir, class_name, img))
    
    print("Data split completed successfully!")

# %%
Train_Test_Split(source_dir,target_dir,split_ratio)
# Out:
# Data split completed successfully!

# %%
WIDTH = 64
HEIGHT = 64
BATCH_SIZE = 32
TRAIN_DIR=r'genres_train_val_split_data/genres/train/'
val_dir = r'genres_train_val_split_data/genres/val/'

# data prep
train_datagen = ImageDataGenerator(
    rescale=1./255.,validation_split=0.25)


train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(HEIGHT, WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical')

validation_gen = train_datagen.flow_from_directory(
    val_dir,target_size = (HEIGHT,WIDTH),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical'
 )
# Out:
# Found 800 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=(64,64,3)))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.compile(optimizers.RMSprop(learning_rate=0.0005, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# C:\Users\WIN10\Desktop\IIT Kanpur ML AI Course\Deep Learning\tfenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\WIN10\Desktop\IIT Kanpur ML AI Course\Deep Learning\tfenv\Lib\site-packages\keras\src\optimizers\base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 62, 62, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 31, 31, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 31, 31, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 29, 29, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 29, 29, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,679,626 (10.22 MB)
#  Trainable params: 2,679,626 (10.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size

model.fit(train_generator,validation_data=validation_gen,epochs=150)
# Out:
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.8495 - loss: 0.3771 - val_accuracy: 0.6350 - val_loss: 1.6115
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - accuracy: 0.8779 - loss: 0.3352 - val_accuracy: 0.6650 - val_loss: 1.6054
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9033 - loss: 0.2730 - val_accuracy: 0.5900 - val_loss: 1.7581
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.9153 - loss: 0.2529 - val_accuracy: 0.6150 - val_loss: 1.9061
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 0.8885 - loss: 0.2973 - val_accuracy: 0.6300 - val_loss: 1.7696
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.8905 - loss: 0.3439 - val_accuracy: 0.6350 - val_loss: 1.7691
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9069 - loss: 0.2497 - val_accuracy: 0.5850 - val_loss: 2.1401
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9190 - loss: 0.2362 - val_accuracy: 0.6050 - val_loss: 1.8222
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.9431 - loss: 0.1792 - val_accuracy: 0.5600 - val_loss: 2.0492
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.9049 - loss: 0.2439 - val_accuracy: 0.6450 - val_loss: 1.7982
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.9055 - loss: 0.2401 - val_accuracy: 0.6000 - val_loss: 1.9677
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.9290 - loss: 0.2187 - val_accuracy: 0.6550 - val_loss: 2.0021
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.9136 - loss: 0.2296 - val_accuracy: 0.6150 - val_loss: 2.0330
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 262ms/step - accuracy: 0.9379 - loss: 0.2007 - val_accuracy: 0.6050 - val_loss: 2.1562
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9072 - loss: 0.2636 - val_accuracy: 0.6200 - val_loss: 1.9542
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9388 - loss: 0.1587 - val_accuracy: 0.6350 - val_loss: 2.4499
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9509 - loss: 0.1655 - val_accuracy: 0.6350 - val_loss: 1.8424
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.9447 - loss: 0.1639 - val_accuracy: 0.6400 - val_loss: 1.6974
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.9549 - loss: 0.1228 - val_accuracy: 0.6050 - val_loss: 1.9239
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.9443 - loss: 0.1630 - val_accuracy: 0.6400 - val_loss: 2.0101
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - accuracy: 0.9678 - loss: 0.1119 - val_accuracy: 0.6100 - val_loss: 2.2423
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9440 - loss: 0.1477 - val_accuracy: 0.6150 - val_loss: 2.0491
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.9635 - loss: 0.1094 - val_accuracy: 0.6550 - val_loss: 2.0321
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 0.9560 - loss: 0.1230 - val_accuracy: 0.6450 - val_loss: 2.1579
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 234ms/step - accuracy: 0.9616 - loss: 0.1019 - val_accuracy: 0.5300 - val_loss: 3.4386
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9383 - loss: 0.1825 - val_accuracy: 0.5850 - val_loss: 2.3293
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9661 - loss: 0.1022 - val_accuracy: 0.6650 - val_loss: 2.0697
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.9654 - loss: 0.1016 - val_accuracy: 0.6450 - val_loss: 2.1639
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.9663 - loss: 0.1152 - val_accuracy: 0.6300 - val_loss: 2.1847
# Epoch 30/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - accuracy: 0.9548 - loss: 0.1373 - val_accuracy: 0.6600 - val_loss: 2.1396
# Epoch 31/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9703 - loss: 0.0842 - val_accuracy: 0.6300 - val_loss: 2.2830
# Epoch 32/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9720 - loss: 0.0714 - val_accuracy: 0.6150 - val_loss: 2.8800
# Epoch 33/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9374 - loss: 0.2428 - val_accuracy: 0.5850 - val_loss: 2.9402
# Epoch 34/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9713 - loss: 0.1082 - val_accuracy: 0.6300 - val_loss: 2.0949
# Epoch 35/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.9671 - loss: 0.0962 - val_accuracy: 0.5650 - val_loss: 2.2764
# Epoch 36/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9563 - loss: 0.1315 - val_accuracy: 0.6400 - val_loss: 2.4193
# Epoch 37/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9696 - loss: 0.0996 - val_accuracy: 0.6400 - val_loss: 2.1077
# Epoch 38/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.9815 - loss: 0.0868 - val_accuracy: 0.6000 - val_loss: 2.4008
# Epoch 39/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - accuracy: 0.9671 - loss: 0.0897 - val_accuracy: 0.6050 - val_loss: 2.8566
# Epoch 40/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9488 - loss: 0.1529 - val_accuracy: 0.5800 - val_loss: 3.0129
# Epoch 41/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9426 - loss: 0.1668 - val_accuracy: 0.6050 - val_loss: 2.7491
# Epoch 42/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.9692 - loss: 0.0929 - val_accuracy: 0.6050 - val_loss: 2.4736
# Epoch 43/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 0.9642 - loss: 0.1134 - val_accuracy: 0.6300 - val_loss: 2.5166
# Epoch 44/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 262ms/step - accuracy: 0.9856 - loss: 0.0501 - val_accuracy: 0.6500 - val_loss: 2.5938
# Epoch 45/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9528 - loss: 0.1009 - val_accuracy: 0.6150 - val_loss: 2.8899
# Epoch 46/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9600 - loss: 0.1246 - val_accuracy: 0.6400 - val_loss: 2.5363
# Epoch 47/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.9578 - loss: 0.1180 - val_accuracy: 0.6250 - val_loss: 2.3703
# Epoch 48/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step - accuracy: 0.9762 - loss: 0.0552 - val_accuracy: 0.5700 - val_loss: 2.5938
# Epoch 49/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - accuracy: 0.9568 - loss: 0.1895 - val_accuracy: 0.6250 - val_loss: 2.2354
# Epoch 50/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9627 - loss: 0.1181 - val_accuracy: 0.6150 - val_loss: 2.8237
# Epoch 51/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9741 - loss: 0.0766 - val_accuracy: 0.6100 - val_loss: 3.0267
# Epoch 52/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - accuracy: 0.9634 - loss: 0.1311 - val_accuracy: 0.6150 - val_loss: 2.6839
# Epoch 53/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.9651 - loss: 0.1211 - val_accuracy: 0.6250 - val_loss: 2.1897
# Epoch 54/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.9797 - loss: 0.0590 - val_accuracy: 0.5900 - val_loss: 2.2623
# Epoch 55/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9703 - loss: 0.0701 - val_accuracy: 0.6200 - val_loss: 3.1232
# Epoch 56/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 267ms/step - accuracy: 0.9798 - loss: 0.0640 - val_accuracy: 0.6000 - val_loss: 3.1660
# Epoch 57/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9711 - loss: 0.0949 - val_accuracy: 0.5950 - val_loss: 2.6932
# Epoch 58/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9773 - loss: 0.0708 - val_accuracy: 0.6050 - val_loss: 2.9917
# Epoch 59/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - accuracy: 0.9723 - loss: 0.0832 - val_accuracy: 0.6250 - val_loss: 3.0788
# Epoch 60/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9786 - loss: 0.0628 - val_accuracy: 0.6550 - val_loss: 2.7835
# Epoch 61/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.9788 - loss: 0.0652 - val_accuracy: 0.6200 - val_loss: 3.5780
# Epoch 62/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 270ms/step - accuracy: 0.9866 - loss: 0.0628 - val_accuracy: 0.6300 - val_loss: 3.1525
# Epoch 63/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 277ms/step - accuracy: 0.9818 - loss: 0.0522 - val_accuracy: 0.5450 - val_loss: 3.2272
# Epoch 64/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 289ms/step - accuracy: 0.9771 - loss: 0.0600 - val_accuracy: 0.6000 - val_loss: 2.8272
# Epoch 65/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9794 - loss: 0.0666 - val_accuracy: 0.6050 - val_loss: 2.8477
# Epoch 66/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - accuracy: 0.9624 - loss: 0.1167 - val_accuracy: 0.6050 - val_loss: 2.9455
# Epoch 67/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 282ms/step - accuracy: 0.9655 - loss: 0.0708 - val_accuracy: 0.6300 - val_loss: 3.0805
# Epoch 68/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.9762 - loss: 0.0745 - val_accuracy: 0.6150 - val_loss: 2.9570
# Epoch 69/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.9832 - loss: 0.0841 - val_accuracy: 0.6150 - val_loss: 3.0483
# Epoch 70/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9666 - loss: 0.1038 - val_accuracy: 0.6250 - val_loss: 2.6721
# Epoch 71/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - accuracy: 0.9756 - loss: 0.0644 - val_accuracy: 0.6600 - val_loss: 2.5179
# Epoch 72/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9768 - loss: 0.0554 - val_accuracy: 0.6300 - val_loss: 2.7714
# Epoch 73/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - accuracy: 0.9901 - loss: 0.0412 - val_accuracy: 0.6050 - val_loss: 2.9042
# Epoch 74/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9830 - loss: 0.0631 - val_accuracy: 0.6000 - val_loss: 3.4656
# Epoch 75/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9789 - loss: 0.0717 - val_accuracy: 0.6150 - val_loss: 2.9242
# Epoch 76/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.9855 - loss: 0.0551 - val_accuracy: 0.6350 - val_loss: 2.6852
# Epoch 77/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9928 - loss: 0.0263 - val_accuracy: 0.6350 - val_loss: 2.9763
# Epoch 78/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.9698 - loss: 0.0710 - val_accuracy: 0.5600 - val_loss: 3.3756
# Epoch 79/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9481 - loss: 0.1638 - val_accuracy: 0.6150 - val_loss: 3.1930
# Epoch 80/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.9866 - loss: 0.0371 - val_accuracy: 0.6250 - val_loss: 3.3366
# Epoch 81/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.9695 - loss: 0.1278 - val_accuracy: 0.6400 - val_loss: 2.8268
# Epoch 82/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step - accuracy: 0.9777 - loss: 0.0528 - val_accuracy: 0.6100 - val_loss: 3.0661
# Epoch 83/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9717 - loss: 0.0677 - val_accuracy: 0.5900 - val_loss: 3.5329
# Epoch 84/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9676 - loss: 0.0852 - val_accuracy: 0.6100 - val_loss: 2.9175
# Epoch 85/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9798 - loss: 0.0617 - val_accuracy: 0.6100 - val_loss: 3.2388
# Epoch 86/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.9698 - loss: 0.0956 - val_accuracy: 0.6150 - val_loss: 3.3174
# Epoch 87/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - accuracy: 0.9681 - loss: 0.0663 - val_accuracy: 0.6600 - val_loss: 3.3047
# Epoch 88/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9892 - loss: 0.0416 - val_accuracy: 0.6350 - val_loss: 3.6356
# Epoch 89/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 0.9672 - loss: 0.1066 - val_accuracy: 0.6500 - val_loss: 2.7723
# Epoch 90/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 0.9763 - loss: 0.0858 - val_accuracy: 0.6300 - val_loss: 3.0591
# Epoch 91/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9903 - loss: 0.0239 - val_accuracy: 0.6350 - val_loss: 3.6200
# Epoch 92/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9743 - loss: 0.0961 - val_accuracy: 0.6200 - val_loss: 3.0704
# Epoch 93/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - accuracy: 0.9837 - loss: 0.0395 - val_accuracy: 0.6300 - val_loss: 2.9144
# Epoch 94/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9695 - loss: 0.1121 - val_accuracy: 0.6150 - val_loss: 3.2869
# Epoch 95/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9790 - loss: 0.1009 - val_accuracy: 0.5800 - val_loss: 3.5892
# Epoch 96/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9729 - loss: 0.0982 - val_accuracy: 0.6300 - val_loss: 3.3616
# Epoch 97/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.9655 - loss: 0.1286 - val_accuracy: 0.6300 - val_loss: 3.0941
# Epoch 98/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.9792 - loss: 0.0580 - val_accuracy: 0.6550 - val_loss: 3.2737
# Epoch 99/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.9757 - loss: 0.0662 - val_accuracy: 0.6350 - val_loss: 3.3226
# Epoch 100/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9828 - loss: 0.0407 - val_accuracy: 0.6450 - val_loss: 3.3069
# Epoch 101/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9782 - loss: 0.0670 - val_accuracy: 0.6350 - val_loss: 2.8287
# Epoch 102/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9890 - loss: 0.0272 - val_accuracy: 0.6000 - val_loss: 3.5565
# Epoch 103/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.9820 - loss: 0.0615 - val_accuracy: 0.6300 - val_loss: 2.8189
# Epoch 104/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9758 - loss: 0.0763 - val_accuracy: 0.6250 - val_loss: 3.1578
# Epoch 105/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.9882 - loss: 0.0340 - val_accuracy: 0.6250 - val_loss: 3.1510
# Epoch 106/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9879 - loss: 0.0553 - val_accuracy: 0.6000 - val_loss: 2.9671
# Epoch 107/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9901 - loss: 0.0322 - val_accuracy: 0.5950 - val_loss: 3.1359
# Epoch 108/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 253ms/step - accuracy: 0.9907 - loss: 0.0301 - val_accuracy: 0.6100 - val_loss: 3.0333
# Epoch 109/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step - accuracy: 0.9832 - loss: 0.0418 - val_accuracy: 0.6400 - val_loss: 3.0464
# Epoch 110/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.9912 - loss: 0.0260 - val_accuracy: 0.6450 - val_loss: 3.2596
# Epoch 111/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9867 - loss: 0.0493 - val_accuracy: 0.6100 - val_loss: 3.1483
# Epoch 112/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - accuracy: 0.9680 - loss: 0.1161 - val_accuracy: 0.6500 - val_loss: 2.8426
# Epoch 113/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9929 - loss: 0.0188 - val_accuracy: 0.6300 - val_loss: 3.5581
# Epoch 114/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9717 - loss: 0.0568 - val_accuracy: 0.6350 - val_loss: 3.2607
# Epoch 115/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9783 - loss: 0.0419 - val_accuracy: 0.6350 - val_loss: 3.1998
# Epoch 116/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.9731 - loss: 0.0822 - val_accuracy: 0.6200 - val_loss: 3.0920
# Epoch 117/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.9835 - loss: 0.0691 - val_accuracy: 0.6000 - val_loss: 3.4347
# Epoch 118/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 0.9859 - loss: 0.0469 - val_accuracy: 0.5850 - val_loss: 3.5047
# Epoch 119/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9825 - loss: 0.0575 - val_accuracy: 0.6100 - val_loss: 3.3904
# Epoch 120/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9798 - loss: 0.0759 - val_accuracy: 0.6300 - val_loss: 3.4424
# Epoch 121/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 302ms/step - accuracy: 0.9939 - loss: 0.0239 - val_accuracy: 0.6850 - val_loss: 3.0411
# Epoch 122/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9910 - loss: 0.0329 - val_accuracy: 0.6450 - val_loss: 3.0199
# Epoch 123/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9880 - loss: 0.0355 - val_accuracy: 0.5600 - val_loss: 3.0491
# Epoch 124/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 296ms/step - accuracy: 0.9870 - loss: 0.0398 - val_accuracy: 0.6300 - val_loss: 3.6432
# Epoch 125/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - accuracy: 0.9680 - loss: 0.1016 - val_accuracy: 0.6350 - val_loss: 3.1202
# Epoch 126/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 0.9775 - loss: 0.0518 - val_accuracy: 0.6100 - val_loss: 3.2306
# Epoch 127/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 0.9920 - loss: 0.0278 - val_accuracy: 0.6400 - val_loss: 3.5444
# Epoch 128/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.9865 - loss: 0.0857 - val_accuracy: 0.6250 - val_loss: 3.5389
# Epoch 129/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step - accuracy: 0.9913 - loss: 0.0298 - val_accuracy: 0.6200 - val_loss: 3.2048
# Epoch 130/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.9781 - loss: 0.0750 - val_accuracy: 0.6100 - val_loss: 3.3096
# Epoch 131/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 282ms/step - accuracy: 0.9938 - loss: 0.0258 - val_accuracy: 0.6550 - val_loss: 3.1562
# Epoch 132/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9814 - loss: 0.0872 - val_accuracy: 0.6200 - val_loss: 2.8218
# Epoch 133/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.9841 - loss: 0.0543 - val_accuracy: 0.6200 - val_loss: 3.0864
# Epoch 134/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9622 - loss: 0.1605 - val_accuracy: 0.6250 - val_loss: 3.7038
# Epoch 135/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9959 - loss: 0.0229 - val_accuracy: 0.6400 - val_loss: 3.5649
# Epoch 136/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.9938 - loss: 0.0230 - val_accuracy: 0.6150 - val_loss: 4.0217
# Epoch 137/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.9906 - loss: 0.0254 - val_accuracy: 0.6100 - val_loss: 4.5157
# Epoch 138/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9878 - loss: 0.0386 - val_accuracy: 0.6350 - val_loss: 4.1108
# Epoch 139/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9894 - loss: 0.0501 - val_accuracy: 0.6200 - val_loss: 3.9773
# Epoch 140/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.9849 - loss: 0.0530 - val_accuracy: 0.6150 - val_loss: 3.6440
# Epoch 141/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.9913 - loss: 0.0262 - val_accuracy: 0.6350 - val_loss: 3.3969
# Epoch 142/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9754 - loss: 0.1027 - val_accuracy: 0.6150 - val_loss: 3.6242
# Epoch 143/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9784 - loss: 0.0611 - val_accuracy: 0.5850 - val_loss: 4.4535
# Epoch 144/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9835 - loss: 0.0517 - val_accuracy: 0.6400 - val_loss: 3.4739
# Epoch 145/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9723 - loss: 0.0630 - val_accuracy: 0.6400 - val_loss: 3.7113
# Epoch 146/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.9902 - loss: 0.0548 - val_accuracy: 0.6400 - val_loss: 3.2998
# Epoch 147/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.9842 - loss: 0.0443 - val_accuracy: 0.6550 - val_loss: 3.6504
# Epoch 148/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9889 - loss: 0.0373 - val_accuracy: 0.6500 - val_loss: 3.2124
# Epoch 149/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 251ms/step - accuracy: 0.9884 - loss: 0.0306 - val_accuracy: 0.6150 - val_loss: 4.2520
# Epoch 150/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.9768 - loss: 0.0924 - val_accuracy: 0.6500 - val_loss: 3.8397
